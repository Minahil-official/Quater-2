# %% [markdown]
# <a href="https://colab.research.google.com/github/Minahil-official/Quater-2/blob/main/image_chat_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY_1')
# Out:
# 'AIzaSyDCnLlWna1UxFko_0l_vN3tDXOfeOa1Nl0'

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=userdata.get('GOOGLE_API_KEY_1'))

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import PIL.Image as img
image = img.open("AI_image.jpeg")
display.display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168>

# %%
prompt = ("explian the image")

# %%
response = model.generate_content([image,prompt])
print(response.text)
# Out:
# That's an image depicting a futuristic business meeting centered around Artificial Intelligence (AI).  Here's a breakdown of the visual elements and their meaning:
#
# * **Central Focus:  AI Brain:** A stylized human head outline is formed from circuit boards, with the letter "AI" prominently displayed within the brain itself. This represents AI as the core topic of discussion.
#
# * **Surrounding Elements:**  Numerous icons and holographic-like images surround the AI brain, representing various aspects and applications of AI:
#
#     * **Robots:** Various types of robots, both humanoid and mechanical, symbolize AI's potential in robotics and automation.
#     * **Technological Devices:**  Cameras, sensors, and other technological components represent the hardware and infrastructure of AI systems.
#     * **Data Spheres:**  Globular images represent data streams, illustrating the vast amounts of information processed by AI.
# ...

# %%
import requests
from io import BytesIO
from PIL import Image
import IPython.display as display

# %%
url = "https://media.istockphoto.com/id/1452604857/photo/businessman-touching-the-brain-working-of-artificial-intelligence-automation-predictive.jpg?s=612x612&w=0&k=20&c=GkAOxzduJbUKpS2-LX_l6jSKtyhdKlnPMo2ito4xpR4="
response = requests.get(url)
img = Image.open(BytesIO(response.content))
display.display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x383>
